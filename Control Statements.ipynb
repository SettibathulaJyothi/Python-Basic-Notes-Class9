# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-9/blob/main/Control%20Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color=blue>Control Statements**
# * A program is a set of instructions given to a computer to do a specific task
# * The order of these instructions controls the flow of a program
# * There are three important ways to control the flow of program which are interpreted by any programming language in a structured manner
# * These are :
#   * Sequential Statements
#   * Selection Statements
#   * Iterative Statements

# %% [markdown]
# # **<font color=red>1.Sequential Statements**
# * A step-by-step process of executing code is called sequential flow of control
# * This is the default flow of execution of a program
# * It means the computer will run the code ,one line at a time ,starting from line 1,followed by line 2 and so on until it reaches the last line of the program.

# %% [markdown]
# **Program 1: Input the first name and last name from the user and display the full name**\
#
# ***Algorithm:***\
# Step1:Start\
# Step2:Input Fristname and Lastname\
# Step3:Fullname=firstname+lastname\
# Step4:Dispaly Fullname\
# Step5:Stop
#
# ***Flowchart:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Source Code:***

# %%
FirstName=input("Enter First Name:")
LastName=input("Enter Last Name:")
FullName=FirstName+" "+LastName
print("Hello "+FullName+" welcome to the world of python")
# Out:
# Enter First Name:Jyothi
# Enter Last Name:Settibathula
# Hello Jyothi Settibathula welcome to the world of python

# %% [markdown]
# **Program 2:Input the length and breadth of a rectangle.Calculate the area and perimeter**
#
# ***Algorithm:***\
# Step1:Start\
# Step2:Input Length,Breadth\
# Step3:Area=Length*Breadth\
# Step4:Perimeter=2(Length + Breadth)\
# Step5:Display "Area is",Area\
# Step6:Display "Perimeter is",Perimeter\
# Step7:Stop
#
# ***Flowchart:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Source Code:***

# %%
Length=int(input('Enter Length: '))
Breadth=int(input('Enter Breadth: '))
Area=Length*Breadth
Perimeter=2*(Length+Breadth)
print("Area is:", Area)
print("Perimeter:", Perimeter)
# Out:
# Enter Length: 22
# Enter Breadth: 33
# Area is: 726
# Perimeter: 110

# %% [markdown]
# # **<font color=red>2.Selection Statements**
# * In python selection flow of control is achieved through conditional statements
# * In conditional or selectional statements ,flow of control is changed based on a condition.We specify the condition in the program,which evaluates to wither 'True' or 'False'
#
# ##**<font color=green>i)The if statement</font>**
# The syntax is as follows:\
# **<font color=0065a6>&emsp;if ( condition ) :\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; //statements </font>**\
# where,
#   * <font color=blue>if <font color=black>is a reserved keyword
#   * <font color=blue>condition <font color=black>can be any relational or logical expression
#   * <font color=blue>statements <font color=black>are always indented can be single or a block

# %% [markdown]
# **Program 3: To input the percentage of a student and award "Certificate of Excellence" if the student gets more than 80%**
#
# **Algorithm:**\
# Step1:Start\
# Step2:Input Percentage\
# Step3:if percentage is more than 80 then\
# &emsp;&emsp;Display "Congratulations"\
# &emsp;&emsp;Display "You are awarded-'Certificate of Excellence'\
# Step4:Stop
#
# **Flowchart:**
#
# ![image.png](data:image/png;base64,...)
#
#
# **Source Code**

# %%
percentage=int(input("enter your percentage:"))
if percentage>80:
  print("Congratulations")
  print("You are awarded-'Certificate of Excellence'")
# Out:
# enter your percentage:89
# Congratulations
# You are awarded-'Certificate of Excellence'

# %% [markdown]
# **Program 4: To input day of the week and in case it is SUNDAY then extra cookie as a reward point to be given with the order.**
#
# **Algorithm:**\
# Step1:Start\
# Step2:Input weekday\
# Step3:if weekday is same as "SUNDAY" then\
# &emsp;&emsp;Display "Reward point-Chocolate Cookie FREE!"\
# Step4:Stop
#
# **Flowchart:**
#
# ![image.png](data:image/png;base64,...)
#
# **Source Code**

# %%
weekday=input("Enter day of the week: ")
if weekday=="SUNDAY":
  print("Reward point-Chocolate Cookie FREE ! ")
# Out:
# Enter day of the week: SUNDAY
# Reward point-Chocolate Cookie FREE !

# %% [markdown]
# ##**<font color=green>ii) The if...else Statement**
# * When the condition is True then the statements  indented just below the if statement will execute
# * When the condition is False then the statements  indented just below the else  statement will execute
# * Synatx:
# <font color=0065a6>&emsp;&emsp;&emsp; **if(condition):\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; //Statements for True\
# &emsp;&emsp;&emsp;else:\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;//Statements for False**
# * <font color=blue>if and else  <font color=black>are reserved keyword
# * <font color=blue>condition  <font color=black>can be any relation or logical expression
# * <font color=blue>statements  <font color=black>are always indented and can be single or a block

# %% [markdown]
# **Program 5: To input two numbers and display the bigger of the two numbers.**
#
# **Algorithm:**
# <font color=blue>
# Step 1:Start\
# Step 2:Input N1,N2\
# Step 3:if N1 is greater than N2 then\
# &emsp;&emsp;Display "N1 is bigger"\
# Step 4:else\
# &emsp;&emsp;Display "N2 is bigger"\
# Step 5:Stop
# </font>
#
# **Flowchart:**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# **Source Code:**

# %%
N1=int(input("Enter First number:"))
N2=int(input("Enter Second number:"))
if N1>N2:
  print(N1,"is bigger")
else:
  print(N2,"is bigger")
# Out:
# Enter First number:34
# Enter Second number:45
# 45 is bigger

# %% [markdown]
# **Program 6: To input a number and display whether it is even or odd**
#
# **Algorithm:**
# <font color=blue>
# Step 1:Start\
# Step 2:Input Num\
# Step 3:if Num is divisible by 2 then\
# &emsp;&emsp;Display "Num is EVEN"\
# Step 4:else\
# &emsp;&emsp;Display "Num is ODD\
# Step 5:Stop
# </font>
#
# **FlowChart:**
#
#
# ![image.png](data:image/png;base64,...)
#
# **Source Code:**

# %%
Num=int(input("Enter a Number:"))
if Num%2==0:
  print(Num,"is Even")
else:
  print(Num,"is odd")
# Out:
# Enter a Number:23
# 23 is odd

# %% [markdown]
# ##**<font color=green>ii) The if...elif....else Statement**
# * When there are multiple condition in the program then it is handled by using elif statement
# * When the if condition is False then the elif statements  indented just below the elif statement will execute
# * In case all elif conditions are false then else statements are executed.
# * Synatx:
# <font color=0065a6>&emsp;&emsp;&emsp;**if(Condition 1):\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; //Statements 1\
# &emsp;&emsp;&emsp; elif(Condition 2):\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; //Statements 2\
# &emsp;&emsp;&emsp; elif(Condition 3):\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; //Statements 3\
# &emsp;&emsp;&emsp; ..........\
# &emsp;&emsp;&emsp;else:\
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;//Statements execute when all above conditions are False**
#
#
# * <font color=green>**if, elif, else**  <font color=black>are reserved keyword
# * <font color=green>**condition 1,condition 2,condition 3,...,** <font color=black>can be any expression
# * <font color=green>**statements 1,statements 2,statements3** <font color=black>are always indented can be single or a block of statements

# %% [markdown]
# **Program 7:To input two numbers and an operator from the user.Display the result calculated based on the operator entered**
#
# **Algorithm:**
# <font color=blue>
# Step 1:Start\
# Step 2:Input N1,N2,op\
# Step 3:if op is same as that of '+' then\
# &emsp;&emsp;Display N1+N2\
# Step 4:else ,if op is same as that of '-' then\
# &emsp;&emsp;Display N1-N2\
# Step 5:else ,if op is same as that of '*' then\
# &emsp;&emsp;Display N1*N2\
# Step 6:else\
# &emsp;&emsp;Display "Sorry!Invalid Operator\
# Step 7:Stop
# </font>
#
# **Flowchart:**
#
#
# ![image.png](data:image/png;base64,...)
#
# **Source Code:**
