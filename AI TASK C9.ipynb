# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-9/blob/main/AI%20TASK%20C9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**<font color="red">AI TASK 3</font>**

# %% [markdown]
# **Make a flowchart for displaying even numbers from 2 to 20.**

# %% [markdown]
# #**<font color="red" >AI TASK 4</font>**

# %% [markdown]
# Colab-a free jupyter notebook environment that runs entirely in the cloud allows you to write and execute Python Code.
# Type https://colab.research.google.com to create your online Python notebooks which ca simultaneously edited by the members with whom you have shared your code in Colab.
# This process is similar to te way you edit documents you have shared your code in Colab.This process is similar to the way you edit documents in Google Docs,Google Sheets or Gogle Slides.

# %% [markdown]
# #**<font color="red">AI TASK 5</font>**

# %% [markdown]
# **Solve the following expressions using the operator precedence.**

# %%
10+20/5-3*2
# Out:
# 8.0

# %%
5*(10+5)+10-5
# Out:
# 80

# %% [markdown]
# # **<font color="red">AI TASK 6</font>**

# %% [markdown]
# **1.Type "import this" in your python IDLE,and you will find a poem written by Tim Peters,a major contribute to the Python Community.**
# **Ans.** The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.\
# Explicit is better than implicit.\
# Simple is better than complex.\
# Complex is better than complicated.\
# Flat is better than nested.\
# Sparse is better than dense.\
# Readability counts.\
# Special cases aren't special enough to break the rules.\
# Although practicality beats purity.\
# Errors should never pass silently.\
# Unless explicitly silenced.\
# In the face of ambiguity, refuse the temptation to guess.\
# There should be one-- and preferably only one --obvious way to do it.\
# Although that way may not be obvious at first unless you're Dutch.\
# Now is better than never.\
# Although never is often better than *right* now.\
# If the implementation is hard to explain, it's a bad idea.\
# If the implementation is easy to explain, it may be a good idea.\
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2.Input a radius of  a circle.Calculate the area and perimeter of circle**
#
# ***Algorithm:***\
# Step 1: Start\
# Step 2: Input Radius\
# Step 3: Area=3.14* radius *radius \
# Step 4: Perimeter=2 * 3.14 * radius\
# Step 5: Display "Area is: ",Area\
# Step 6: Dispaly "Perimeter is: ",Perimeter\
# Step 7:Stop
#
# ***Flowchart:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Source Code:***

# %%
radius=int(input("Enter radius:"))
Area=3.14*radius*radius
Perimeter=2*3.14*radius
print("Area is: ", Area)
print( "Perimeter is:", Perimeter)
# Out:
# Enter radius:4
# Area is:  50.24
# Perimeter is: 25.12
