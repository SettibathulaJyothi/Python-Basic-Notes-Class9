# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basic-Notes-Class9/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Operators in python**
# Operators are special symbols used to perform mathematical operations,logical and relational operations on variables and values.

# %% [markdown]
# # **Arithmetic Operators**
# **Addition**

# %%
2+4
# Out:
# 6

# %%
2.0+4
# Out:
# 6.0

# %%
"hi"+"all"
# Out:
# 'hiall'

# %% [markdown]
# **Subtraction**

# %%
6-2
# Out:
# 4

# %%
6.0-2
# Out:
# 4.0

# %% [markdown]
#  **Multiplication**

# %%
2*3
# Out:
# 6

# %%
1.5*2
# Out:
# 3.0

# %%
"hi"*3
# Out:
# 'hihihi'

# %% [markdown]
#  **Division**

# %%
4/2
# Out:
# 2.0

# %%
6.0/2
# Out:
# 3.0

# %%
6/2.0
# Out:
# 3.0

# %%
11/2
# Out:
# 5.5

# %% [markdown]
# **Remainder or Modulus**

# %%
5%2
# Out:
# 1

# %%
16%11
# Out:
# 5

# %% [markdown]
# **Exponential**

# %%
5**2
# Out:
# 25

# %%
1.5**2
# Out:
# 2.25

# %% [markdown]
# **Floor Division**

# %%
11/2
# Out:
# 5.5

# %%
-11/2
# Out:
# -5.5

# %%
13//4
# Out:
# 3
