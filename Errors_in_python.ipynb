# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-9/blob/main/Errors_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Errors in python**
# * Sometimes while writing code we migth make mistakes.These are called Errors
# * There are 3 types of errors;
#   * Syntax Error
#   * Logical Error
#   * Runtime Error

# %% [markdown]
# ***1.Syntax Error***
# * Syntax refers to the rules for writing code in python language
# * A syntax error occurs when these rules are violated
# * This is most common error made by programmer
# * Syntax errors can result from typing error,incorect indentation,or incorrect arguments to function
# * Python encounters a syntax error\
#
# **Eaxmple:**

# %%
a+b=c     #cannot assign to operator
# Out:
#   File "/tmp/ipykernel_4899/1001618493.py", line 1
#     a+b=c
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
myname=Jyothi     #EOL while scanning string literal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4899/2897749519.py in <cell line: 0>()
# ----> 1 myname=Jyothi
#
# NameError: name 'Jyothi' is not defined

# %%
a=5
b=10
  c=a+b
# Out:
#   File "/tmp/ipykernel_4899/2138592737.py", line 3
#     c=a+b
#     ^
# IndentationError: unexpected indent

# %%
print("Python"))
# Out:
#   File "/tmp/ipykernel_4899/1813601316.py", line 1
#     print("Python"))
#                    ^
# SyntaxError: unmatched ')'

# %% [markdown]
# ***2.Logical Error***
# * This kind of error is difficult to find since the program will run correctly but the desired output is not achieved
# * It happens when if we give a wrong formula for the calculation to be done

# %%
p=marks1+marks2/2       #instead of (marks+marks2)/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4899/1302644388.py in <cell line: 0>()
# ----> 1 p=marks1+marks2/2       #instead of (marks+marks2)/2
#
# NameError: name 'marks1' is not defined

# %%
p=2+1+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4899/2967210389.py in <cell line: 0>()
# ----> 1 p=2+1+b
#
# NameError: name 'b' is not defined

# %% [markdown]
# ***3.Runtime Error***
# * Occurs during execution of a program and can result from various issues such as incorrect input/output,undefined object errors,or division by zero
# * These errors stops the exceution of code,making them challenging to debug

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
c=a/b
print(c)
# Out:
# Enter a number:5
# Enter a number:0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_4899/2671613191.py in <cell line: 0>()
#       1 a=int(input("Enter a number:"))
#       2 b=int(input("Enter a number:"))
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero
